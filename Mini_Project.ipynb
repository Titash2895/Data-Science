# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv('fifa.csv')

# %%
data.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo    Value  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  €110.5M
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png     €77M
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  €118.5M
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png     €72M
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png    €102M
#
#     Wage Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 0  €565K           Left                       5.0        4.0          4.0
# 1  €405K          Right                       5.0        4.0          5.0
# 2  €290K          Right                       5.0        5.0          5.0
# 3  €260K          Right                       4.0        3.0          1.0
# 4  €355K          Right                       4.0        5.0          4.0
#
#         Work Rate   Body Type Position  Jersey Number        Joined  \
# 0  Medium/ Medium       Messi       RF           10.0   Jul 1, 2004
# 1       High/ Low  C. Ronaldo       ST            7.0  Jul 10, 2018
# 2    High/ Medium      Neymar       LW           10.0   Aug 3, 2017
# 3  Medium/ Medium        Lean       GK            1.0   Jul 1, 2011
# 4      High/ High      Normal      RCM            7.0  Aug 30, 2015
#
#   Loaned From Contract Valid Until Height  Weight  Crossing  Finishing  \
# 0         NaN                 2021    5'7  159lbs      84.0       95.0
# 1         NaN                 2022    6'2  183lbs      84.0       94.0
# 2         NaN                 2022    5'9  150lbs      79.0       87.0
# 3         NaN                 2020    6'4  168lbs      17.0       13.0
# 4         NaN                 2023   5'11  154lbs      93.0       82.0
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  \
# 0             70.0          90.0     86.0       97.0   93.0        94.0
# 1             89.0          81.0     87.0       88.0   81.0        76.0
# 2             62.0          84.0     84.0       96.0   88.0        87.0
# 3             21.0          50.0     13.0       18.0   21.0        19.0
# 4             55.0          92.0     82.0       86.0   85.0        83.0
#
#    LongPassing  BallControl  Acceleration  SprintSpeed  Agility  Reactions  \
# 0         87.0         96.0          91.0         86.0     91.0       95.0
# 1         77.0         94.0          89.0         91.0     87.0       96.0
# 2         78.0         95.0          94.0         90.0     96.0       94.0
# 3         51.0         42.0          57.0         58.0     60.0       90.0
# 4         91.0         91.0          78.0         76.0     79.0       91.0
#
#    Balance  ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0     95.0       85.0     68.0     72.0      59.0       94.0        48.0
# 1     70.0       95.0     95.0     88.0      79.0       93.0        63.0
# 2     84.0       80.0     61.0     81.0      49.0       82.0        56.0
# 3     43.0       31.0     67.0     43.0      64.0       12.0        38.0
# 4     77.0       91.0     63.0     90.0      75.0       91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0           22.0         94.0    94.0       75.0       96.0     33.0
# 1           29.0         95.0    82.0       85.0       95.0     28.0
# 2           36.0         89.0    87.0       81.0       94.0     27.0
# 3           30.0         12.0    68.0       40.0       68.0     15.0
# 4           61.0         87.0    94.0       79.0       88.0     68.0
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0            28.0           26.0       6.0        11.0       15.0
# 1            31.0           23.0       7.0        11.0       15.0
# 2            24.0           33.0       9.0         9.0       15.0
# 3            21.0           13.0      90.0        85.0       87.0
# 4            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes Release Clause
# 0           14.0         8.0        €226.5M
# 1           14.0        11.0        €127.1M
# 2           15.0        11.0        €228.1M
# 3           88.0        94.0        €138.6M
# 4           10.0        13.0        €196.4M

# %%
data.isna().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Crossing                       48
# Finishing                      48
# HeadingAccuracy                48
# ShortPassing                   48
# Volleys                        48
# Dribbling                      48
# Curve                          48
# FKAccuracy                     48
# LongPassing                    48
# BallControl                    48
# Acceleration                   48
# SprintSpeed                    48
# Agility                        48
# Reactions                      48
# Balance                        48
# ShotPower                      48
# Jumping                        48
# Stamina                        48
# Strength                       48
# LongShots                      48
# Aggression                     48
# Interceptions                  48
# Positioning                    48
# Vision                         48
# Penalties                      48
# Composure                      48
# Marking                        48
# StandingTackle                 48
# SlidingTackle                  48
# GKDiving                       48
# GKHandling                     48
# GKKicking                      48
# GKPositioning                  48
# GKReflexes                     48
# Release Clause               1564
# dtype: int64

# %%
#data.dropna(thresh=53,inplace=True)

# %% [markdown]
# # Column Conversion

# %%
data['Value']=data['Value'].str.strip('€MK')

# %%
data['Wage']=data['Wage'].str.strip('€MK')

# %%
data[['Value','Wage']]=data[['Value','Wage']].astype('float64')

# %%
data[['Value','Wage']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   18207 non-null  float64
#  1   Wage    18207 non-null  float64
# dtypes: float64(2)
# memory usage: 284.6 KB

# %%
data['Joined']=data['Joined'].str.slice(-4)

# %%
data['Joined']=data['Joined'].fillna('3000')

# %%
data['Joined'].isna().sum()
# Out:
# 0

# %%
data[['Joined']]=data[['Joined']].astype('int64')

# %%
data[['Joined']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Joined  18207 non-null  int64
# dtypes: int64(1)
# memory usage: 142.4 KB

# %%
data['Contract Valid Until']=pd.to_datetime(data['Contract Valid Until'])

# %%
data[['Contract Valid Until']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 1 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Contract Valid Until  17918 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 142.4 KB

# %%
data['Height']=data['Height'].str.replace('\'','.')

# %%
data['Height'].head()
# Out:
# 0     5.7
# 1     6.2
# 2     5.9
# 3     6.4
# 4    5.11
# Name: Height, dtype: object

# %%
data['Weight']=data['Weight'].str.slice(0,-3,1)

# %%
data['Weight'].head()
# Out:
# 0    159
# 1    183
# 2    150
# 3    168
# 4    154
# Name: Weight, dtype: object

# %%
data['Weight']=data['Weight'].astype('float64')

# %%
data[['Weight']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  18159 non-null  float64
# dtypes: float64(1)
# memory usage: 142.4 KB

# %%
data['Release Clause']=data['Release Clause'].str.strip('€MK')

# %%
data['Release Clause'].head()
# Out:
# 0    226.5
# 1    127.1
# 2    228.1
# 3    138.6
# 4    196.4
# Name: Release Clause, dtype: object

# %%
data['Release Clause']=data['Release Clause'].astype('float64')

# %%
data[['Release Clause']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Release Clause  16643 non-null  float64
# dtypes: float64(1)
# memory usage: 142.4 KB

# %% [markdown]
# # Null Handling

# %%
data.isna().sum().value_counts()
# Out:
# 48       42
# 0        12
# 60        2
# 241       1
# 16943     1
# 289       1
# 1564      1
# dtype: int64

# %% [markdown]
# We are going with mean imputation forthe below columns which are required for analysis

# %%
data['International Reputation']=data['International Reputation'].fillna(data['International Reputation'].mean())

# %%
data['Height']=data['Height'].astype('float64')
data['Height']=data['Height'].fillna(data['Height'].mean())

# %%
data['Weight']=data['Weight'].fillna(data['Weight'].mean())

# %%
data['Position']=data['Position'].fillna(data['Position'].mode()[0])

# %%
data['Release Clause'].describe()
# Out:
# count    16643.000000
# mean       228.201274
# std        299.251866
# min          1.000000
# 25%          2.500000
# 50%         19.800000
# 75%        431.000000
# max        999.000000
# Name: Release Clause, dtype: float64

# %%
sns.violinplot(data['Release Clause'])
# Out:
# E:\anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Release Clause'>

# %% [markdown]
# For Release Clause column we are going with median as it consists of extreme values

# %%
data['Release Clause']=data['Release Clause'].fillna(data['Release Clause'].median())

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.isna())
plt.savefig('htmp.png')

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# # 1.	Plot the distribution of Overall rating for all players

# %%
plt.figure(figsize=(15,8))
sns.violinplot(data['Overall'])
plt.savefig('overall.png')
# Out:
# E:\anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Overall rating of the players are normally distributed with mean and median near 70. The distribution is left skewed

# %% [markdown]
# # 2.	Generate pair plots for the following variables:
# Overall, Value, Wage, International Reputation, Height, Weight, Release Clause

# %%
df=data[['Overall','Value','Wage','International Reputation','Height','Weight','Release Clause']]

# %%
df.head()
# Out:
#    Overall  Value   Wage  International Reputation  Height  Weight  \
# 0       94  110.5  565.0                       5.0    5.70   159.0
# 1       94   77.0  405.0                       5.0    6.20   183.0
# 2       92  118.5  290.0                       5.0    5.90   150.0
# 3       91   72.0  260.0                       4.0    6.40   168.0
# 4       91  102.0  355.0                       4.0    5.11   154.0
#
#    Release Clause
# 0           226.5
# 1           127.1
# 2           228.1
# 3           138.6
# 4           196.4

# %%
df.isna().sum()
# Out:
# Overall                     0
# Value                       0
# Wage                        0
# International Reputation    0
# Height                      0
# Weight                      0
# Release Clause              0
# dtype: int64

# %%
sns.pairplot(df)
plt.savefig('pairplot.png')

# %% [markdown]
# # 3.	Generate a table containing the top 20 players ranked by Overall score and whose contract expires in 2020.

# %%
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %%
df_ov=data.sort_values('Overall',ascending=False)
df_ov=df_ov[df_ov['Contract Valid Until'].dt.year==2020]

# %%
top=df_ov.head(20)

# %%
top.head()
# Out:
#         ID          Name  Age                                           Photo  \
# 3   193080        De Gea   27  https://cdn.sofifa.org/players/4/19/193080.png
# 5   183277     E. Hazard   27  https://cdn.sofifa.org/players/4/19/183277.png
# 6   177003     L. Modrić   32  https://cdn.sofifa.org/players/4/19/177003.png
# 8   155862  Sergio Ramos   32  https://cdn.sofifa.org/players/4/19/155862.png
# 13  168542   David Silva   32  https://cdn.sofifa.org/players/4/19/168542.png
#
#    Nationality                                 Flag  Overall  Potential  \
# 3        Spain  https://cdn.sofifa.org/flags/45.png       91         93
# 5      Belgium   https://cdn.sofifa.org/flags/7.png       91         91
# 6      Croatia  https://cdn.sofifa.org/flags/10.png       91         91
# 8        Spain  https://cdn.sofifa.org/flags/45.png       91         91
# 13       Spain  https://cdn.sofifa.org/flags/45.png       90         90
#
#                  Club                                     Club Logo  Value  \
# 3   Manchester United   https://cdn.sofifa.org/teams/2/light/11.png   72.0
# 5             Chelsea    https://cdn.sofifa.org/teams/2/light/5.png   93.0
# 6         Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png   67.0
# 8         Real Madrid  https://cdn.sofifa.org/teams/2/light/243.png   51.0
# 13    Manchester City   https://cdn.sofifa.org/teams/2/light/10.png   60.0
#
#      Wage Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 3   260.0          Right                       4.0        3.0          1.0
# 5   340.0          Right                       4.0        4.0          4.0
# 6   420.0          Right                       4.0        4.0          4.0
# 8   380.0          Right                       4.0        3.0          3.0
# 13  285.0           Left                       4.0        2.0          4.0
#
#          Work Rate Body Type Position  Jersey Number  Joined Loaned From  \
# 3   Medium/ Medium      Lean       GK            1.0    2011         NaN
# 5     High/ Medium    Normal       LF           10.0    2012         NaN
# 6       High/ High      Lean      RCM           10.0    2012         NaN
# 8     High/ Medium    Normal      RCB           15.0    2005         NaN
# 13    High/ Medium    Normal      LCM           21.0    2010         NaN
#
#    Contract Valid Until  Height  Weight  Crossing  Finishing  HeadingAccuracy  \
# 3            2020-01-01     6.4   168.0      17.0       13.0             21.0
# 5            2020-01-01     5.8   163.0      81.0       84.0             61.0
# 6            2020-01-01     5.8   146.0      86.0       72.0             55.0
# 8            2020-01-01     6.0   181.0      66.0       60.0             91.0
# 13           2020-01-01     5.8   148.0      84.0       76.0             54.0
#
#     ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# 3           50.0     13.0       18.0   21.0        19.0         51.0
# 5           89.0     80.0       95.0   83.0        79.0         83.0
# 6           93.0     76.0       90.0   85.0        78.0         88.0
# 8           78.0     66.0       63.0   74.0        72.0         77.0
# 13          93.0     82.0       89.0   82.0        77.0         87.0
#
#     BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# 3          42.0          57.0         58.0     60.0       90.0     43.0
# 5          94.0          94.0         88.0     95.0       90.0     94.0
# 6          93.0          80.0         72.0     93.0       90.0     94.0
# 8          84.0          76.0         75.0     78.0       85.0     66.0
# 13         94.0          70.0         64.0     92.0       90.0     90.0
#
#     ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 3        31.0     67.0     43.0      64.0       12.0        38.0
# 5        82.0     56.0     83.0      66.0       80.0        54.0
# 6        79.0     68.0     89.0      58.0       82.0        62.0
# 8        79.0     93.0     84.0      83.0       59.0        88.0
# 13       72.0     64.0     78.0      52.0       75.0        57.0
#
#     Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 3            30.0         12.0    68.0       40.0       68.0     15.0
# 5            41.0         87.0    89.0       86.0       91.0     34.0
# 6            83.0         79.0    92.0       82.0       84.0     60.0
# 8            90.0         60.0    63.0       75.0       82.0     87.0
# 13           50.0         89.0    92.0       75.0       93.0     59.0
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 3             21.0           13.0      90.0        85.0       87.0
# 5             27.0           22.0      11.0        12.0        6.0
# 6             76.0           73.0      13.0         9.0        7.0
# 8             92.0           91.0      11.0         8.0        9.0
# 13            53.0           29.0       6.0        15.0        7.0
#
#     GKPositioning  GKReflexes  Release Clause
# 3            88.0        94.0           138.6
# 5             8.0         8.0           172.1
# 6            14.0         9.0           137.4
# 8             7.0        11.0           104.6
# 13            6.0        12.0           111.0

# %% [markdown]
# # a)	What would the average wage for this set of players be?

# %%
print('Average wage of this set of players is',top.Wage.mean())
# Out:
# Average wage of this set of players is 206.4

# %% [markdown]
# # b)	What is the average age?

# %%
print('Average age of this set of players is',top.Age.mean())
# Out:
# Average age of this set of players is 30.6

# %% [markdown]
# # c)	Is there a correlation between the Overall rating and Value for these players?

# %%
top[['Overall','Value']].corr()
# Out:
#           Overall     Value
# Overall  1.000000  0.766756
# Value    0.766756  1.000000

# %%
sns.lineplot(top['Overall'],top['Value'])
plt.savefig('Value.png')
# Out:
# E:\anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# There is a correlation between the Overall rating and Value for these players, with increase in overall rating 76% chances are the that Value will also increase

# %% [markdown]
# # 4.	Generate tables containing the top 5 players by Overall rating for each unique position

# %%
data['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
df_pos=data.groupby('Position',group_keys=False)
df_top=df_pos.apply(lambda x:x.sort_values('Overall',ascending=False).head())

# %%
df_top.head()
# Out:
#         ID             Name  Age  \
# 17  194765     A. Griezmann   27
# 31  190460       C. Eriksen   26
# 61  201942  Roberto Firmino   26
# 66  189596        T. Müller   28
# 74  176635          M. Özil   29
#
#                                              Photo Nationality  \
# 17  https://cdn.sofifa.org/players/4/19/194765.png      France
# 31  https://cdn.sofifa.org/players/4/19/190460.png     Denmark
# 61  https://cdn.sofifa.org/players/4/19/201942.png      Brazil
# 66  https://cdn.sofifa.org/players/4/19/189596.png     Germany
# 74  https://cdn.sofifa.org/players/4/19/176635.png     Germany
#
#                                    Flag  Overall  Potential  \
# 17  https://cdn.sofifa.org/flags/18.png       89         90
# 31  https://cdn.sofifa.org/flags/13.png       88         91
# 61  https://cdn.sofifa.org/flags/54.png       86         87
# 66  https://cdn.sofifa.org/flags/21.png       86         86
# 74  https://cdn.sofifa.org/flags/21.png       86         86
#
#                  Club                                     Club Logo  Value  \
# 17    Atlético Madrid  https://cdn.sofifa.org/teams/2/light/240.png   78.0
# 31  Tottenham Hotspur   https://cdn.sofifa.org/teams/2/light/18.png   73.5
# 61          Liverpool    https://cdn.sofifa.org/teams/2/light/9.png   53.0
# 66  FC Bayern München   https://cdn.sofifa.org/teams/2/light/21.png   45.0
# 74            Arsenal    https://cdn.sofifa.org/teams/2/light/1.png   43.5
#
#      Wage Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 17  145.0           Left                       4.0        3.0          4.0
# 31  205.0          Right                       3.0        5.0          4.0
# 61  195.0          Right                       3.0        4.0          4.0
# 66  135.0          Right                       4.0        4.0          3.0
# 74  190.0           Left                       4.0        2.0          4.0
#
#        Work Rate Body Type Position  Jersey Number  Joined Loaned From  \
# 17    High/ High      Lean      CAM            7.0    2014         NaN
# 31  High/ Medium      Lean      CAM           10.0    2013         NaN
# 61    High/ High      Lean      CAM            9.0    2015         NaN
# 66    High/ High      Lean      CAM           13.0    2008         NaN
# 74   Medium/ Low      Lean      CAM           10.0    2013         NaN
#
#    Contract Valid Until  Height  Weight  Crossing  Finishing  HeadingAccuracy  \
# 17           2023-01-01    5.90   161.0      82.0       90.0             84.0
# 31           2020-01-01    5.11   168.0      88.0       80.0             52.0
# 61           2023-01-01    5.11   168.0      72.0       87.0             77.0
# 66           2021-01-01    6.10   165.0      79.0       87.0             82.0
# 74           2021-01-01    5.11   168.0      83.0       73.0             54.0
#
#     ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# 17          83.0     87.0       88.0   84.0        78.0         76.0
# 31          91.0     77.0       84.0   86.0        87.0         88.0
# 61          86.0     81.0       87.0   80.0        65.0         75.0
# 66          83.0     84.0       75.0   81.0        59.0         72.0
# 74          89.0     80.0       84.0   84.0        77.0         82.0
#
#     BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# 17         90.0          88.0         85.0     90.0       90.0     80.0
# 31         91.0          75.0         73.0     79.0       88.0     81.0
# 61         88.0          78.0         77.0     80.0       86.0     81.0
# 66         82.0          73.0         75.0     75.0       91.0     72.0
# 74         90.0          72.0         69.0     79.0       84.0     70.0
#
#     ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 17       80.0     90.0     83.0      62.0       82.0        69.0
# 31       84.0     50.0     92.0      58.0       89.0        46.0
# 61       81.0     81.0     90.0      74.0       76.0        73.0
# 66       78.0     81.0     87.0      68.0       80.0        57.0
# 74       70.0     48.0     69.0      57.0       75.0        48.0
#
#     Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 17           35.0         91.0    83.0       79.0       87.0     59.0
# 31           56.0         83.0    91.0       67.0       88.0     59.0
# 61           58.0         87.0    85.0       72.0       87.0     60.0
# 66           58.0         92.0    85.0       60.0       83.0     44.0
# 74           24.0         83.0    91.0       67.0       82.0     24.0
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 17            47.0           48.0      14.0         8.0       14.0
# 31            57.0           22.0       9.0        14.0        7.0
# 61            64.0           42.0       8.0        11.0        9.0
# 66            41.0           44.0       6.0         7.0       11.0
# 74            16.0           19.0       6.0        14.0       10.0
#
#     GKPositioning  GKReflexes  Release Clause
# 17           13.0        14.0           165.8
# 31            7.0         6.0           141.5
# 61            6.0        10.0           104.7
# 66           14.0        14.0            74.3
# 74            6.0        14.0            82.7

# %%
grp=df_top.groupby('Position')
g=list(grp)

# %%
len(df_top.Position.unique())
# Out:
# 27

# %% [markdown]
# Since there are 27 unique positions each table having top 5 players from all unique positioncan be accessed by g[n][1]
# where n=1 to 27 in accordance with the positions

# %%
g[2][1]
# Out:
#          ID             Name  Age  \
# 20   189511  Sergio Busquets   29
# 27   200145         Casemiro   26
# 72   180206        M. Pjanić   28
# 75   135507      Fernandinho   33
# 118  209499          Fabinho   24
#
#                                               Photo         Nationality  \
# 20   https://cdn.sofifa.org/players/4/19/189511.png               Spain
# 27   https://cdn.sofifa.org/players/4/19/200145.png              Brazil
# 72   https://cdn.sofifa.org/players/4/19/180206.png  Bosnia Herzegovina
# 75   https://cdn.sofifa.org/players/4/19/135507.png              Brazil
# 118  https://cdn.sofifa.org/players/4/19/209499.png              Brazil
#
#                                     Flag  Overall  Potential             Club  \
# 20   https://cdn.sofifa.org/flags/45.png       89         89     FC Barcelona
# 27   https://cdn.sofifa.org/flags/54.png       88         90      Real Madrid
# 72    https://cdn.sofifa.org/flags/8.png       86         86         Juventus
# 75   https://cdn.sofifa.org/flags/54.png       86         86  Manchester City
# 118  https://cdn.sofifa.org/flags/54.png       84         88        Liverpool
#
#                                         Club Logo  Value   Wage  \
# 20   https://cdn.sofifa.org/teams/2/light/241.png   51.5  315.0
# 27   https://cdn.sofifa.org/teams/2/light/243.png   59.5  285.0
# 72    https://cdn.sofifa.org/teams/2/light/45.png   44.0  180.0
# 75    https://cdn.sofifa.org/teams/2/light/10.png   18.0  185.0
# 118    https://cdn.sofifa.org/teams/2/light/9.png   34.0  120.0
#
#     Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 20           Right                       4.0        3.0          3.0
# 27           Right                       3.0        3.0          2.0
# 72           Right                       3.0        4.0          3.0
# 75           Right                       3.0        4.0          3.0
# 118          Right                       3.0        2.0          3.0
#
#           Work Rate Body Type Position  Jersey Number  Joined Loaned From  \
# 20   Medium/ Medium      Lean      CDM            5.0    2008         NaN
# 27     Medium/ High    Normal      CDM           14.0    2013         NaN
# 72   Medium/ Medium    Normal      CDM            5.0    2016         NaN
# 75     Medium/ High      Lean      CDM           25.0    2013         NaN
# 118  Medium/ Medium      Lean      CDM            3.0    2018         NaN
#
#     Contract Valid Until  Height  Weight  Crossing  Finishing  \
# 20            2023-01-01     6.2   168.0      62.0       67.0
# 27            2021-01-01     6.1   185.0      52.0       59.0
# 72            2023-01-01     5.1   159.0      80.0       60.0
# 75            2020-01-01     5.1   148.0      68.0       69.0
# 118           2023-01-01     6.2   172.0      79.0       66.0
#
#      HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  \
# 20              68.0          89.0     44.0       80.0   66.0        68.0
# 27              76.0          85.0     53.0       69.0   59.0        74.0
# 72              60.0          89.0     72.0       86.0   86.0        92.0
# 75              63.0          85.0     74.0       77.0   70.0        72.0
# 118             75.0          83.0     47.0       76.0   71.0        53.0
#
#      LongPassing  BallControl  Acceleration  SprintSpeed  Agility  Reactions  \
# 20          82.0         88.0          50.0         52.0     66.0       87.0
# 27          82.0         78.0          59.0         65.0     62.0       84.0
# 72          85.0         89.0          66.0         66.0     77.0       84.0
# 75          81.0         82.0          68.0         67.0     72.0       86.0
# 118         78.0         82.0          69.0         72.0     69.0       83.0
#
#      Balance  ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 20      52.0       61.0     66.0     86.0      77.0       54.0        85.0
# 27      66.0       86.0     88.0     87.0      89.0       79.0        87.0
# 72      79.0       78.0     61.0     78.0      66.0       82.0        70.0
# 75      78.0       83.0     76.0     79.0      76.0       78.0        87.0
# 118     67.0       78.0     75.0     92.0      79.0       65.0        85.0
#
#      Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 20            87.0         77.0    87.0       60.0       90.0     90.0
# 27            87.0         69.0    77.0       66.0       84.0     88.0
# 72            78.0         70.0    88.0       79.0       86.0     75.0
# 75            88.0         70.0    75.0       61.0       79.0     85.0
# 118           84.0         70.0    75.0       91.0       84.0     83.0
#
#      StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 20             86.0           80.0       5.0         8.0       13.0
# 27             90.0           87.0      13.0        14.0       16.0
# 72             74.0           70.0       7.0         7.0       13.0
# 75             85.0           80.0      12.0        11.0        5.0
# 118            86.0           84.0      13.0        12.0        6.0
#
#      GKPositioning  GKReflexes  Release Clause
# 20             9.0        13.0           105.6
# 27            12.0        12.0           126.4
# 72             7.0         8.0            72.6
# 75            13.0         7.0            33.3
# 118            8.0         8.0            67.2

# %% [markdown]
# Above is the table for position CDM

# %% [markdown]
# # a)	Are there any players appearing in more than one Table. Please point out such players.

# %%
players=data.Name.value_counts()
players[players>1]
# Out:
# J. Rodríguez    11
# Paulinho         8
# J. Williams      7
# R. Williams      7
# Felipe           6
#                 ..
# T. Robinson      2
# C. Martin        2
# M. Díaz          2
# C. Burgess       2
# J. Fernández     2
# Name: Name, Length: 762, dtype: int64

# %% [markdown]
# Above players appearing in more than one Table

# %% [markdown]
# # b)	What is the average wage one can expect to pay for the top 5 in every position?

# %%
df_wage=df_top.groupby('Position')[['Wage']].mean()

# %%
df_wage=df_wage.reset_index()

# %%
plt.figure(figsize=(15,8))
sns.barplot(df_wage['Position'],df_wage['Wage'])
plt.savefig('wage.png')
# Out:
# E:\anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_wage
# Out:
#    Position   Wage
# 0       CAM  174.0
# 1        CB  139.6
# 2       CDM  217.0
# 3        CF   47.4
# 4        CM  130.6
# 5        GK  192.8
# 6       LAM   81.6
# 7        LB  177.2
# 8       LCB  162.0
# 9       LCM  184.4
# 10      LDM  126.6
# 11       LF  121.2
# 12       LM  164.6
# 13       LS  130.2
# 14       LW  261.0
# 15      LWB   34.2
# 16      RAM   45.4
# 17       RB  155.4
# 18      RCB  231.0
# 19      RCM  240.8
# 20      RDM  105.0
# 21       RF  148.0
# 22       RM  131.4
# 23       RS  132.2
# 24       RW  202.0
# 25      RWB   44.2
# 26       ST  294.0

# %%
for i in range(len(df_wage)):
    print(f'For {df_wage.iloc[i:i+1,:1]}')
    print(f'{df_wage.iloc[i:i+1,1:2]}')
# Out:
# For   Position
# 0      CAM
#     Wage
# 0  174.0
# For   Position
# 1       CB
#     Wage
# 1  139.6
# For   Position
# 2      CDM
#     Wage
# 2  217.0
# For   Position
# 3       CF
#    Wage
# 3  47.4
# For   Position
# 4       CM
#     Wage
# 4  130.6
# For   Position
# 5       GK
#     Wage
# 5  192.8
# For   Position
# 6      LAM
#    Wage
# 6  81.6
# For   Position
# 7       LB
#     Wage
# 7  177.2
# For   Position
# 8      LCB
#     Wage
# 8  162.0
# For   Position
# 9      LCM
#     Wage
# 9  184.4
# For    Position
# 10      LDM
#      Wage
# 10  126.6
# For    Position
# 11       LF
#      Wage
# 11  121.2
# For    Position
# 12       LM
#      Wage
# 12  164.6
# For    Position
# 13       LS
#      Wage
# 13  130.2
# For    Position
# 14       LW
#      Wage
# 14  261.0
# For    Position
# 15      LWB
#     Wage
# 15  34.2
# For    Position
# 16      RAM
#     Wage
# 16  45.4
# For    Position
# 17       RB
#      Wage
# 17  155.4
# For    Position
# 18      RCB
#      Wage
# 18  231.0
# For    Position
# 19      RCM
#      Wage
# 19  240.8
# For    Position
# 20      RDM
#      Wage
# 20  105.0
# For    Position
# 21       RF
#      Wage
# 21  148.0
# For    Position
# 22       RM
#      Wage
# 22  131.4
# For    Position
# 23       RS
#      Wage
# 23  132.2
# For    Position
# 24       RW
#      Wage
# 24  202.0
# For    Position
# 25      RWB
#     Wage
# 25  44.2
# For    Position
# 26       ST
#      Wage
# 26  294.0
